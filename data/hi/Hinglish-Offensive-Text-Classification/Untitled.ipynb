# %%
import pandas as pd
df = pd.read_csv('HOT_Dataset_modified.csv',names=['hate', 'text'], header=None)

# %%
df
# Out:
#                                                                                                                    hate  \
# 0.0 @saud5683 @Mutayyab420 @shivang598 @Ranask35 @m... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# NaN NaN                                                NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# 2.0 Banti hai empowered woman, feminism pe gyan pel... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# NaN NaN                                                NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# 2.0 RT @kim_jong_korea: @updatingwait @Acutereply A... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# ...                                                                                                                 ...
# 1.0 @zyanmalik0011 @SariaW @asadowaisi @ZairaWasimm... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# ...
